# %% [markdown]
# ##Import

# %%
# %run ../utils/download_utils

# %% [markdown]
# ## Params & Inputs

# %%
#dbutils.widgets.removeAll()

# %%
#"https://data.insideairbnb.com/france/auvergne-rhone-alpes/lyon/2025-09-18/data/listings.csv.gz"
#"https://data.insideairbnb.com/france/auvergne-rhone-alpes/lyon/2025-09-18/data/calendar.csv.gz"
#"https://data.insideairbnb.com/france/auvergne-rhone-alpes/lyon/2025-09-18/data/reviews.csv.gz"
#"https://data.insideairbnb.com/france/auvergne-rhone-alpes/lyon/2025-09-18/visualisations/listings.csv"
#"https://data.insideairbnb.com/france/auvergne-rhone-alpes/lyon/2025-09-18/visualisations/reviews.csv"
#"https://data.insideairbnb.com/france/auvergne-rhone-alpes/lyon/2025-09-18/visualisations/neighbourhoods.csv"
#"https://data.insideairbnb.com/france/auvergne-rhone-alpes/lyon/2025-09-18/visualisations/neighbourhoods.geojson"
dbutils.widgets.text("city", "lyon")
user_email = dbutils.notebook.entry_point.getDbutils().notebook().getContext().userName().get()
#dbutils.widgets.text("table_bronze", "Listing_detail")
dbutils.widgets.text("file", "listings.csv.gz")
dbutils.widgets.text("url_file", "https://data.insideairbnb.com/france/auvergne-rhone-alpes/lyon/2025-09-18/data/listings.csv.gz")
dbutils.widgets.text("destination", f"/Workspace/Users/{user_email}/data")

# %%
# -----------------------------------------------------------------------------
# 1. Récupération des paramètres (widgets)
# -----------------------------------------------------------------------------
city = dbutils.widgets.get("city").strip().lower()
file_name = dbutils.widgets.get("file")
url = dbutils.widgets.get("url_file")
base_path = dbutils.widgets.get("destination")

# %% [markdown]
# ##Construction du chemin de destination

# %%
target_folder = f"{base_path}/{city}"
target_file_path = f"{target_folder}/{file_name}"

print(f"Dossier cible          : {target_folder}")
print(f"Fichier sera enregistré : {target_file_path}")

# %% [markdown]
# ##Download

# %%
download_web_file(dbutils, url, target_folder, file_name)

# %%
    # Supprimer fichiers .crc et fichiers cachés
    for f in dbutils.fs.ls(target_folder):
        if f.name.startswith(".") or f.name.endswith(".crc"):
            dbutils.fs.rm(f.path, True)
